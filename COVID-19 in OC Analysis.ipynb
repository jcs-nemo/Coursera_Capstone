# %% [markdown]
# # COVID-19 Healthcare Capacity in Orange County, CA

# %% [markdown]
# ## 1. Import Libraries
#
# The libraries I will be using are: Pandas, NumPy, JSON, GeoPy, Matplotlib, Skikit-learn, and Folium.

# %%
import pandas as pd
import numpy as np
import json
# !pip install geocoder
import geocoder as geocoder
# !pip install geopy
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium

print ('Libraries imported')
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 17.1MB/s ta 0:00:01
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 7.8MB/s eta 0:00:011
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1
# Libraries imported

# %% [markdown]
# ## 2. Build Dataframe
#
# The Orange County government website archives COVID-19 statistics data. I use Pandas instand of Beautifulsoup to scrape data because Pandas has easier coding. The data contains the name of cities in Orange County, populations and total COVID-19 cases in each city. We will use these datasets later.

# %%
data = pd.read_html('https://occovid19.ochealthinfo.com/coronavirus-in-oc')
 
for df in data:
    if(str(np.array_equal(np.array(df),np.array(df)))=="True"): 
        df = pd.DataFrame(df)    
    break

df.columns = ['City', 'Population', 'Total Cases']
df = df[1:-3]
df.head()
# Out:
#           City Population Total Cases
# 1  Aliso Viejo      51372          18
# 2      Anaheim     359339         316
# 3         Brea      45606          20
# 4   Buena Park      83384          76
# 5   Costa Mesa     115830          38

# %%
# Drop Population Column and reindex dataframe

df.drop('Population', axis = 1, inplace = True)
df = df.reset_index(drop = True)
df.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#           City Total Cases
# 0  Aliso Viejo          18
# 1      Anaheim         316
# 2         Brea          20
# 3   Buena Park          76
# 4   Costa Mesa          38

# %% [markdown]
# ## 3. Get City Coordinates
#
# I use Geocoder to find geographic locations for the obtained cities above. This process will give me latitudes and longitudes for each city in Orange County.

# %%
def getLatLong(row):
    lat_lng_coords = None
    search_query = '{}, California,USA'.format(row)
    try:
        while(lat_lng_coords is None):
            g = geocoder.arcgis(search_query)
            lat_lng_coords = g.latlng
    except IndexError:
        latitude = 0.0
        longitude = 0.0
        print('BACKUP')
        return [latitude,longitude]

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    print(latitude, longitude)
    return [latitude, longitude]

coords_list = df['City'].apply(getLatLong).tolist()
# Out:
# 33.56964000000005 -117.72690999999998
# 33.83286000000004 -117.91523999999998
# 33.917590000000075 -117.88898999999998
# 33.86520000000007 -117.99803999999995
# 33.66389000000004 -117.90238999999997
# 33.63404000000003 -117.58623999999998
# 33.82434000000006 -118.03722999999997
# 33.480540000000076 -117.69764999999995
# 33.709070000000054 -117.95027999999996
# 33.870330000000024 -117.92895999999996
# 33.77607000000006 -117.93610999999999
# 33.67893000000004 -118.00156999999996
# 33.68730000000005 -117.82590999999996
# 33.93187000000006 -117.94347999999997
# 33.84847000000008 -118.03726999999998
# 33.570460000000026 -117.63926999999995
# 33.54536000000007 -117.78152999999998
# 33.601860000000045 -117.69094999999999
# 33.56065000000007 -117.70821999999998
# 33.61256000000003 -117.71871999999996
# 33.62825000000004 -117.71742999999998
# 33.80316000000005 -118.07661999999999
# 33.74469000000005 -117.98646999999994
# 33.620070000000055 -117.67708999999996
# 33.61703000000006 -117.93032999999997
# 33.787870000000055 -117.85070999999999
# 33.871210000000076 -117.86019999999996
# 33.48058000000003 -117.56754999999998
# 33.63482000000005 -117.60299999999995
# 33.430240000000026 -117.60697999999996
# 33.49789000000004 -117.66538999999995
# 33.74958000000004 -117.87445999999994
# 33.742560000000026 -118.10516999999999
# 33.80295000000007 -117.99623999999994
# 33.66092000000003 -117.59021999999999
# 33.74425000000008 -117.81882999999999
# 33.81407000000007 -117.82056999999998
# 33.75931000000003 -117.98575999999997
# 33.89152000000007 -117.82431999999994

# %%
df[['City Latitude', 'City Longitude']] = pd.DataFrame(coords_list, columns = ['Latitude', 'Longitude'])
df
# Out:
#                       City Total Cases  City Latitude  City Longitude
# 0              Aliso Viejo          18       33.56964      -117.72691
# 1                  Anaheim         316       33.83286      -117.91524
# 2                     Brea          20       33.91759      -117.88899
# 3               Buena Park          76       33.86520      -117.99804
# 4               Costa Mesa          38       33.66389      -117.90239
# 5             Coto de Caza           5       33.63404      -117.58624
# 6                  Cypress          42       33.82434      -118.03723
# 7               Dana Point          23       33.48054      -117.69765
# 8          Fountain Valley          31       33.70907      -117.95028
# 9                Fullerton          74       33.87033      -117.92896
# 10            Garden Grove          99       33.77607      -117.93611
# 11        Huntington Beach         214       33.67893      -118.00157
# 12                  Irvine         126       33.68730      -117.82591
# 13                La Habra          46       33.93187      -117.94348
# 14                La Palma          14       33.84847      -118.03727
# 15            Ladera Ranch          12       33.57046      -117.63927
# 16            Laguna Beach          37       33.54536      -117.78153
# 17            Laguna Hills          20       33.60186      -117.69095
# 18           Laguna Niguel          32       33.56065      -117.70822
# 19            Laguna Woods           8       33.61256      -117.71872
# 20             Lake Forest          28       33.62825      -117.71743
# 21            Los Alamitos          22       33.80316      -118.07662
# 22             Midway City           6       33.74469      -117.98647
# 23           Mission Viejo          42       33.62007      -117.67709
# 24           Newport Beach          97       33.61703      -117.93033
# 25                  Orange          84       33.78787      -117.85071
# 26               Placentia          52       33.87121      -117.86020
# 27    Rancho Mission Viejo           6       33.48058      -117.56755
# 28  Rancho Santa Margarita          14       33.63482      -117.60300
# 29            San Clemente          45       33.43024      -117.60698
# 30     San Juan Capistrano          24       33.49789      -117.66539
# 31               Santa Ana         330       33.74958      -117.87446
# 32              Seal Beach          11       33.74256      -118.10517
# 33                 Stanton          23       33.80295      -117.99624
# 34          Trabuco Canyon          10       33.66092      -117.59022
# 35                  Tustin          38       33.74425      -117.81883
# 36              Villa Park           5       33.81407      -117.82057
# 37             Westminster          40       33.75931      -117.98576
# 38             Yorba Linda          48       33.89152      -117.82432

# %% [markdown]
# ## 4. Binning the COVID-19 Cases
#
# Let's visualize the total cases in each city by deploying bar graph. Then we devide the data into four bins:
# 1. Low Risk: 5~82 cases
# 2. Medium Risk: 82~159 cases
# 3. High Risk: 159~236 cases
# 4. Extreme High Risk: 236~313 cases

# %%
# Change the "Total Cases" column type from object to integer
df["Total Cases"] = df["Total Cases"].astype(str).astype(int)

# Generate 5 pins by categorizing total cases
bins = np.linspace(min(df["Total Cases"]), max(df["Total Cases"]), 5)
bins
# Out:
# array([  5.  ,  86.25, 167.5 , 248.75, 330.  ])

# %%
group_names = ['Low Risk', 'Medium Risk', 'High Risk', 'Extreme High Risk']
df['Risk Level'] = pd.cut(df['Total Cases'], bins, labels=group_names, include_lowest=True )
df.head()
# Out:
#           City  Total Cases  Latitude  Longitude         Risk Level
# 0  Aliso Viejo           18  33.56964 -117.72691           Low Risk
# 1      Anaheim          316  33.83286 -117.91524  Extreme High Risk
# 2         Brea           20  33.91759 -117.88899           Low Risk
# 3   Buena Park           76  33.86520 -117.99804           Low Risk
# 4   Costa Mesa           38  33.66389 -117.90239           Low Risk

# %%
# Lets examine the number of cities falls into each bin
print(df["Risk Level"].value_counts())
# Out:
# Low Risk             33
# Medium Risk           3
# Extreme High Risk     2
# High Risk             1
# Name: Risk Level, dtype: int64

# %% [markdown]
# ## 5. Visualize the Bins

# %%
# Create bar chart to visualize the risk distributions in Orange County
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

pyplot.bar(group_names, df["Risk Level"].value_counts(), color = 'r')

plt.pyplot.title('COVID-19 Risk Distribution in Orange County') 
plt.pyplot.ylabel('Number of Cities')
plt.pyplot.xlabel('Risk Level') 

plt.pyplot.show()

# %% [markdown]
# ## 6. Identify Local Hospitals Using Foursqure
#
# Next, by using Foursqure API, we will be able to collect local hospitals geographic information.

# %%
CLIENT_ID = 'K25YJQ3E34V2MXHR20RADQP2RRXKMG3MFBH0EOQXDWPTWIEF'
CLIENT_SECRET = 'PIYHI0QKR0DN3S5ZECN541RABQYUPI4NBWODEH1NMMTIW1IL' 
VERSION = '20180604'
LIMIT = 100

# I choose Irvine as center , and find hospitals within 5000 meters radius. 

irvine_lat = 33.6846
irvine_lng = -117.8265
search_query = 'Hospital'
radius = 5000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    irvine_lat, 
    irvine_lng, 
    VERSION, 
    search_query, 
    radius, 
    LIMIT)
url

results_irvine = requests.get(url).json()
results_irvine
# Out:
# {'meta': {'code': 200, 'requestId': '5eaa4d491835dd05ebd57cfe'},
#  'response': {'venues': [{'id': '4c35f5c37cc0c9b6c6c0f59a',
#     'name': 'Hoag Hospital Irvine',
#     'location': {'address': '16200 Sand Canyon Ave',
#      'crossStreet': 'Alton',
#      'lat': 33.6608041,
#      'lng': -117.7724516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.6608041,
#        'lng': -117.7724516}],
#      'distance': 5664,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['16200 Sand Canyon Ave (Alton)',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4b683d43f964a520936d2be3',
#     'name': 'Kaiser Permanente Hospital',
#     'location': {'address': '6640 Alton Pkwy',
#      'crossStreet': 'at Sand Canyon Ave',
#      'lat': 33.6579474152331,
#      'lng': -117.77413244214989,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.6579474152331,
#        'lng': -117.77413244214989}],
#      'distance': 5686,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['6640 Alton Pkwy (at Sand Canyon Ave)',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4ca684abd971b1f7b82301e1',
#     'name': 'Irvine Valley Veterinary Hospital',
#     'location': {'address': '15435 Jeffrey Road Ste 107',
#      'lat': 33.681055,
#      'lng': -117.77885,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.681055,
#        'lng': -117.77885},
#       {'label': 'entrance', 'lat': 33.680586, 'lng': -117.779415}],
#      'distance': 4431,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['15435 Jeffrey Road Ste 107',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '475170187'},
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4c12b8cca5eb76b0d2b5beb7',
#     'name': 'Animal Hospital of Irvine',
#     'location': {'address': '4200 Trabuco Rd',
#      'crossStreet': 'Culver Dr',
#      'lat': 33.707893,
#      'lng': -117.77936899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.707893,
#        'lng': -117.77936899999999},
#       {'label': 'entrance', 'lat': 33.707943, 'lng': -117.779396}],
#      'distance': 5077,
#      'postalCode': '92620',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['4200 Trabuco Rd (Culver Dr)',
#       'Irvine, CA 92620',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '57d22d6e498e4bb2917c35ba',
#     'name': 'hospital',
#     'location': {'lat': 33.665738,
#      'lng': -117.769588,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.665738,
#        'lng': -117.769588}],
#      'distance': 5674,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Irvine, CA 92618', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5140f805e4b054a20be9107b',
#     'name': 'Santa Ana Veterinary Hospital Inc',
#     'location': {'address': '1933 S Main St',
#      'lat': 33.723051,
#      'lng': -117.867522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.723051,
#        'lng': -117.867522}],
#      'distance': 5723,
#      'postalCode': '92707',
#      'cc': 'US',
#      'city': 'Santa Ana',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1933 S Main St',
#       'Santa Ana, CA 92707',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '407560498'},
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4c12add082a3c9b6a929faf8',
#     'name': 'Stonecreek Animal Hospital',
#     'location': {'address': '4178 Barranca Pkwy',
#      'crossStreet': 'West Yale Loop',
#      'lat': 33.681915667435405,
#      'lng': -117.80591218877079,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.681915667435405,
#        'lng': -117.80591218877079},
#       {'label': 'entrance', 'lat': 33.681466, 'lng': -117.805138}],
#      'distance': 1930,
#      'postalCode': '92604',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['4178 Barranca Pkwy (West Yale Loop)',
#       'Irvine, CA 92604',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e345976bd414b4ca829d2b5',
#     'name': 'Banfield Pet Hospital',
#     'location': {'address': '2237 Park Ave',
#      'lat': 33.700043465630365,
#      'lng': -117.8298731893301,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.700043465630365,
#        'lng': -117.8298731893301},
#       {'label': 'entrance', 'lat': 33.700129, 'lng': -117.829321}],
#      'distance': 1747,
#      'postalCode': '92782',
#      'cc': 'US',
#      'city': 'Tustin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2237 Park Ave',
#       'Tustin, CA 92782',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4c4886b0c047be9afa0c3479',
#     'name': 'St Joseph Hospital',
#     'location': {'address': '4050 Barranca Pkwy',
#      'lat': 33.682415999999996,
#      'lng': -117.807061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.682415999999996,
#        'lng': -117.807061}],
#      'distance': 1816,
#      'postalCode': '92604',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['4050 Barranca Pkwy',
#       'Irvine, CA 92604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5b5ba393b8fd9d002cf533fa',
#     'name': 'Tustin Legacy Animal Hospital',
#     'location': {'address': '15100 Kensington Park Dr Ste 520',
#      'crossStreet': 'Edinger',
#      'lat': 33.7134768,
#      'lng': -117.8149776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.7134768,
#        'lng': -117.8149776}],
#      'distance': 3387,
#      'postalCode': '92782',
#      'cc': 'US',
#      'city': 'Tustin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['15100 Kensington Park Dr Ste 520 (Edinger)',
#       'Tustin, CA 92782',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bd7b8a10b779c749ede05a0',
#     'name': 'Southern California Veterinary Specialty Hospital',
#     'location': {'address': '1371 Reynolds Ave',
#      'crossStreet': 'Redhill',
#      'lat': 33.696673701853264,
#      'lng': -117.85513123050694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.696673701853264,
#        'lng': -117.85513123050694}],
#      'distance': 2973,
#      'postalCode': '92614',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1371 Reynolds Ave (Redhill)',
#       'Irvine, CA 92614',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5d0347862d2fd9002ce717f1',
#     'name': 'BluePearl Pet Hospital',
#     'location': {'address': '1371 Reynolds Ave',
#      'lat': 33.69682,
#      'lng': -117.855031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.69682,
#        'lng': -117.855031}],
#      'distance': 2972,
#      'postalCode': '92614',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1371 Reynolds Ave',
#       'Irvine, CA 92614',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4c262721c11dc9b63e602824',
#     'name': 'The Cat Hospital',
#     'location': {'lat': 33.706461,
#      'lng': -117.805939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.706461,
#        'lng': -117.805939},
#       {'label': 'entrance', 'lat': 33.706551, 'lng': -117.806363}],
#      'distance': 3090,
#      'postalCode': '92780',
#      'cc': 'US',
#      'city': 'Tustin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Tustin, CA 92780', 'United States']},
#     'categories': [],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5c798b16cb3fd2002c77c802',
#     'name': 'VCA Irvine University Park Animal Hospital',
#     'location': {'address': '5301 University Dr',
#      'lat': 33.659467,
#      'lng': -117.80309299999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.659467,
#        'lng': -117.80309299999999},
#       {'label': 'entrance', 'lat': 33.658447, 'lng': -117.803663}],
#      'distance': 3539,
#      'postalCode': '92612',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['5301 University Dr',
#       'Irvine, CA 92612',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5d7020e943c8bd000789f23e',
#     'name': 'Hoag Hospital Imaging',
#     'location': {'address': '16305 Sand Canyon Ave',
#      'crossStreet': 'Alton',
#      'lat': 33.662266,
#      'lng': -117.77404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.662266,
#        'lng': -117.77404}],
#      'distance': 5458,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['16305 Sand Canyon Ave (Alton)',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4d5ebc2c1939a35d53c10cee',
#     'name': 'Alton Animal Hospital',
#     'location': {'lat': 33.68983,
#      'lng': -117.86531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.68983,
#        'lng': -117.86531}],
#      'distance': 3641,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['California', 'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e85e2787ee62475b5fb7fd3',
#     'name': 'Orange Coast Memorial Hospital',
#     'location': {'lat': 33.661222341610355,
#      'lng': -117.78440920185989,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.661222341610355,
#        'lng': -117.78440920185989}],
#      'distance': 4687,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['California', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e69587c483bf2d9e5c1b7bc',
#     'name': 'Kaiser Hospital Irvine ER',
#     'location': {'lat': 33.64772545440766,
#      'lng': -117.83528977260609,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.64772545440766,
#        'lng': -117.83528977260609}],
#      'distance': 4184,
#      'cc': 'US',
#      'state': 'California',
#      'country': 'United States',
#      'formattedAddress': ['California', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '515e67c2e4b0662110fb4d3c',
#     'name': 'hoag hospital irvine 6th floor',
#     'location': {'lat': 33.66144561767578,
#      'lng': -117.77235412597656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.66144561767578,
#        'lng': -117.77235412597656}],
#      'distance': 5639,
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Irvine, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5ca53a7ac824ae002c3ead89',
#     'name': 'Hoag Hospital Visitor Parking',
#     'location': {'address': '16200 Sand Canyon Ave',
#      'lat': 33.660818,
#      'lng': -117.772349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.660818,
#        'lng': -117.772349}],
#      'distance': 5672,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['16200 Sand Canyon Ave',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4fa81851e4b0bbcd4bd6576e',
#     'name': 'Nick Co Hospitality Group',
#     'location': {'lat': 33.693483,
#      'lng': -117.83184399999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.693483,
#        'lng': -117.83184399999999}],
#      'distance': 1105,
#      'postalCode': '92606',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Irvine, CA 92606', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5bb5c4d220dc64002574db87',
#     'name': 'Central Orange County Emergency Animal Hospital',
#     'location': {'address': '3720 Campus Dr., Suite D',
#      'lat': 33.662886,
#      'lng': -117.873733,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.662886,
#        'lng': -117.873733}],
#      'distance': 4998,
#      'postalCode': '92660',
#      'cc': 'US',
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3720 Campus Dr., Suite D',
#       'Newport Beach, CA 92660',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e7215882271d11692a7f2a1',
#     'name': 'Alton Main Animal Hospital',
#     'location': {'address': '3105 S Main St',
#      'lat': 33.70572428333333,
#      'lng': -117.86787818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.70572428333333,
#        'lng': -117.86787818}],
#      'distance': 4496,
#      'postalCode': '92707',
#      'cc': 'US',
#      'city': 'Santa Ana',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3105 S Main St',
#       'Santa Ana, CA 92707',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bace1b6f964a52047153be3',
#     'name': 'Newport Specialty Hospital',
#     'location': {'lat': 33.730446272788896,
#      'lng': -117.8285813072592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.730446272788896,
#        'lng': -117.8285813072592}],
#      'distance': 5107,
#      'postalCode': '92780',
#      'cc': 'US',
#      'city': 'Tustin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Tustin, CA 92780', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4f7b9654e4b041ee79f68c6b',
#     'name': "Jenn's Hospital Room",
#     'location': {'lat': 33.658524,
#      'lng': -117.774439,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.658524,
#        'lng': -117.774439}],
#      'distance': 5629,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Irvine, CA 92618', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '54f11e44498e8773f49080dd',
#     'name': 'Oak Creek Pet Hospital',
#     'location': {'address': '6612 Irvine Center Dr',
#      'lat': 33.6688,
#      'lng': -117.764,
#      'labeledLatLngs': [{'label': 'display', 'lat': 33.6688, 'lng': -117.764}],
#      'distance': 6051,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['6612 Irvine Center Dr',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bc105ca920eb713e5131a2c',
#     'name': 'Arbor Animal Hospital',
#     'location': {'address': '14775 Jeffrey Rd Ste F',
#      'crossStreet': 'Walnut / Jeffery',
#      'lat': 33.688775,
#      'lng': -117.771552,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.688775,
#        'lng': -117.771552},
#       {'label': 'entrance', 'lat': 33.68897, 'lng': -117.771524}],
#      'distance': 5110,
#      'postalCode': '92618',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['14775 Jeffrey Rd Ste F (Walnut / Jeffery)',
#       'Irvine, CA 92618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bc4c183b492d13a2b85aa60',
#     'name': 'Tustana Animal Hospital',
#     'location': {'lat': 33.73673915863037,
#      'lng': -117.820398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.73673915863037,
#        'lng': -117.820398},
#       {'label': 'entrance', 'lat': 33.736623, 'lng': -117.820289}],
#      'distance': 5831,
#      'postalCode': '92780',
#      'cc': 'US',
#      'city': 'Tustin',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Tustin, CA 92780', 'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bc0b9c6b492d13a3cbda460',
#     'name': 'northwood animal hospital',
#     'location': {'address': '13925 Yale Ave',
#      'lat': 33.704883,
#      'lng': -117.77280400000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.704883,
#        'lng': -117.77280400000001},
#       {'label': 'entrance', 'lat': 33.705223, 'lng': -117.772603}],
#      'distance': 5461,
#      'postalCode': '92620',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['13925 Yale Ave',
#       'Irvine, CA 92620',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4da3171463b5a35d72620a1a',
#     'name': 'Baker Bristol Pet Hospital',
#     'location': {'address': '2976 Bristol St',
#      'lat': 33.679325,
#      'lng': -117.885328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.679325,
#        'lng': -117.885328},
#       {'label': 'entrance', 'lat': 33.679325, 'lng': -117.885424}],
#      'distance': 5480,
#      'postalCode': '92626',
#      'cc': 'US',
#      'city': 'Costa Mesa',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2976 Bristol St',
#       'Costa Mesa, CA 92626',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4ba15fe4f964a5205db137e3',
#     'name': 'Camino Pet Hospital',
#     'location': {'address': '5408 Walnut Ave',
#      'lat': 33.68960492114493,
#      'lng': -117.76945254514605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.68960492114493,
#        'lng': -117.76945254514605},
#       {'label': 'entrance', 'lat': 33.689189, 'lng': -117.770358}],
#      'distance': 5313,
#      'postalCode': '92604',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['5408 Walnut Ave',
#       'Irvine, CA 92604',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4c8ba0e652a98cfafc9d37e9',
#     'name': 'Central Orange County',
#     'location': {'address': '3720 Campus Dr Ste D',
#      'crossStreet': 'bristol and campus',
#      'lat': 33.662872,
#      'lng': -117.873589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.662872,
#        'lng': -117.873589},
#       {'label': 'entrance', 'lat': 33.663085, 'lng': -117.874018}],
#      'distance': 4988,
#      'postalCode': '92660',
#      'cc': 'US',
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3720 Campus Dr Ste D (bristol and campus)',
#       'Newport Beach, CA 92660',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e49e2bb14951b66ae887b08',
#     'name': 'Evolution Hospitality',
#     'location': {'lat': 33.7156984918414,
#      'lng': -117.84890628341337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.7156984918414,
#        'lng': -117.84890628341337}],
#      'distance': 4036,
#      'cc': 'US',
#      'city': 'Santa Ana',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Santa Ana, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '50c2444fe4b065e8eae84f7e',
#     'name': 'Quail Animal',
#     'location': {'address': '6765 Quail Hill Pkwy',
#      'crossStreet': 'Shady Canyon Trl',
#      'lat': 33.654933783471584,
#      'lng': -117.7783323997556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.654933783471584,
#        'lng': -117.7783323997556}],
#      'distance': 5551,
#      'postalCode': '92603',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['6765 Quail Hill Pkwy (Shady Canyon Trl)',
#       'Irvine, CA 92603',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '85930290'},
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4bce28eac564ef3b4ac8edf0',
#     'name': 'Back Bay Vet',
#     'location': {'address': '4263 Birch St',
#      'lat': 33.6674690246582,
#      'lng': -117.867858886719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.6674690246582,
#        'lng': -117.867858886719}],
#      'distance': 4279,
#      'postalCode': '92660',
#      'cc': 'US',
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['4263 Birch St',
#       'Newport Beach, CA 92660',
#       'United States']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '5147a5727043d435e9f4dc70',
#     'name': 'Rim Hospitality - Corporate Headquarters',
#     'location': {'address': '3990 Westerly Pl Ste 120',
#      'lat': 33.662884000000005,
#      'lng': -117.868214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.662884000000005,
#        'lng': -117.868214}],
#      'distance': 4558,
#      'postalCode': '92660',
#      'cc': 'US',
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3990 Westerly Pl Ste 120',
#       'Newport Beach, CA 92660',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61873929'},
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4e5fe2acc65bfe3fcc586f68',
#     'name': 'Broughton Hospitality',
#     'location': {'address': '20241 SW Birch St',
#      'lat': 33.657962,
#      'lng': -117.876922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.657962,
#        'lng': -117.876922},
#       {'label': 'entrance', 'lat': 33.6579, 'lng': -117.876778}],
#      'distance': 5532,
#      'postalCode': '92660',
#      'cc': 'US',
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['20241 SW Birch St',
#       'Newport Beach, CA 92660',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d127941735',
#       'name': 'Conference Room',
#       'pluralName': 'Conference Rooms',
#       'shortName': 'Conference room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_conferenceroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False},
#    {'id': '4fa069a7e4b0953f4883b62b',
#     'name': 'UCI Hospitality & Dining Services',
#     'location': {'address': 'Uci',
#      'lat': 33.64851872962118,
#      'lng': -117.84267778042087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.64851872962118,
#        'lng': -117.84267778042087}],
#      'distance': 4287,
#      'postalCode': '92697',
#      'cc': 'US',
#      'city': 'Irvine',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Uci', 'Irvine, CA 92697', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588219394',
#     'hasPerk': False}]}}

# %%
venues = results_irvine['response']['venues']
hospital_irvine = json_normalize(venues)
print(hospital_irvine.shape)
hospital_irvine.head()
# Out:
# (38, 18)
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 2  [{'id': '4d954af4a243a5684765b473', 'name': 'V...    False
# 3  [{'id': '4d954af4a243a5684765b473', 'name': 'V...    False
# 4  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
#
#                          id            location.address location.cc  \
# 0  4c35f5c37cc0c9b6c6c0f59a       16200 Sand Canyon Ave          US
# 1  4b683d43f964a520936d2be3             6640 Alton Pkwy          US
# 2  4ca684abd971b1f7b82301e1  15435 Jeffrey Road Ste 107          US
# 3  4c12b8cca5eb76b0d2b5beb7             4200 Trabuco Rd          US
# 4  57d22d6e498e4bb2917c35ba                         NaN          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0        Irvine    United States                Alton               5664
# 1        Irvine    United States   at Sand Canyon Ave               5686
# 2        Irvine    United States                  NaN               4431
# 3        Irvine    United States            Culver Dr               5077
# 4        Irvine    United States                  NaN               5674
#
#                            location.formattedAddress  \
# 0  [16200 Sand Canyon Ave (Alton), Irvine, CA 926...
# 1  [6640 Alton Pkwy (at Sand Canyon Ave), Irvine,...
# 2  [15435 Jeffrey Road Ste 107, Irvine, CA 92618,...
# 3  [4200 Trabuco Rd (Culver Dr), Irvine, CA 92620...
# 4                  [Irvine, CA 92618, United States]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 33.6608041, 'lng'...     33.660804
# 1  [{'label': 'display', 'lat': 33.6579474152331,...     33.657947
# 2  [{'label': 'display', 'lat': 33.681055, 'lng':...     33.681055
# 3  [{'label': 'display', 'lat': 33.707893, 'lng':...     33.707893
# 4  [{'label': 'display', 'lat': 33.665738, 'lng':...     33.665738
#
#    location.lng location.postalCode location.state  \
# 0   -117.772452               92618             CA
# 1   -117.774132               92618             CA
# 2   -117.778850               92618             CA
# 3   -117.779369               92620             CA
# 4   -117.769588               92618             CA
#
#                                 name    referralId venuePage.id
# 0               Hoag Hospital Irvine  v-1588219394          NaN
# 1         Kaiser Permanente Hospital  v-1588219394          NaN
# 2  Irvine Valley Veterinary Hospital  v-1588219394    475170187
# 3          Animal Hospital of Irvine  v-1588219394          NaN
# 4                           hospital  v-1588219394          NaN

# %%
# The dataframe needs to be cleaned.
# We want to keep only hospital name and location. 

filtered_columns = ['name', 'categories', 'location.lat', 'location.lng']
hospital_irvine = hospital_irvine.loc[:, filtered_columns]
print(hospital_irvine.shape)
hospital_irvine.head()
# Out:
# (38, 4)
#                                 name  \
# 0               Hoag Hospital Irvine
# 1         Kaiser Permanente Hospital
# 2  Irvine Valley Veterinary Hospital
# 3          Animal Hospital of Irvine
# 4                           hospital
#
#                                           categories  location.lat  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...     33.660804
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...     33.657947
# 2  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     33.681055
# 3  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     33.707893
# 4  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...     33.665738
#
#    location.lng
# 0   -117.772452
# 1   -117.774132
# 2   -117.778850
# 3   -117.779369
# 4   -117.769588

# %%
# Identify Animal hospitals and drop them off the dataframe.

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
hospital_irvine['categories'] = hospital_irvine.apply(get_category_type, axis=1)
hospital_irvine.columns = [column.split('.')[-1] for column in hospital_irvine.columns]

# Include only Hospitals and Medical Centers
hospital_irvine = hospital_irvine[(hospital_irvine.categories == 'Hospital') | (hospital_irvine.categories == 'Medical Center')]

# Exclude hospital names that contain animal, pet, etc.
hospital_irvine = hospital_irvine[~hospital_irvine['name'].str.contains('Animal')]
hospital_irvine = hospital_irvine[~hospital_irvine['name'].str.contains('Pet')]
hospital_irvine = hospital_irvine[~hospital_irvine['name'].str.contains('Veterinary')]
hospital_irvine = hospital_irvine.reset_index(drop = True)
print(hospital_irvine.shape)
hospital_irvine.head()
# Out:
# (7, 4)
#                              name categories        lat         lng
# 0            Hoag Hospital Irvine   Hospital  33.660804 -117.772452
# 1      Kaiser Permanente Hospital   Hospital  33.657947 -117.774132
# 2                        hospital   Hospital  33.665738 -117.769588
# 3              St Joseph Hospital   Hospital  33.682416 -117.807061
# 4  Orange Coast Memorial Hospital   Hospital  33.661222 -117.784409

# %% [markdown]
# ## 7. Repeat the Process
#
# We iterate the process by finding local hospitals near each city, using Foursqure API.

# %%
def getNearbyHospital(names, latitudes, longitudes, radius=5000):
    
    hospitals_list=[] 
    search_query = 'Hospital'
    
    # create the API request URL
    for name, lat, lng in zip(names, latitudes, longitudes):
        LIMIT=100
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
           CLIENT_ID, 
           CLIENT_SECRET, 
           lat, 
           lng, 
           VERSION, 
           search_query, 
           radius, 
           LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
        #res = results_hos[0]
        #print(res.keys())
        #print((results_hos[0]))

        # return only relevant information for each nearby venue
        hospitals_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],
            v['categories']) for v in results])
        #print (hospitals_list)

    hospitals = pd.DataFrame([hospital for hospital_list in hospitals_list for hospital in hospital_list])
    hospitals.columns = ['City',
                         'City Latitude',
                         'City Longitude',
                         'Hospital', 
                         'Hospital Latitude',
                         'Hospital Longitude',
                         'Categories']
    
    #return(dataframe_filtered)
    return hospitals

# %%
local_hospitals = getNearbyHospital(names=df['City'], 
                                  latitudes=df['City Latitude'], 
                                   longitudes=df['City Longitude'], 
                                   radius=5000)
print(local_hospitals.shape)
local_hospitals.head()
# Out:
# (1228, 7)
#           City  City Latitude  City Longitude  \
# 0  Aliso Viejo       33.56964      -117.72691
# 1  Aliso Viejo       33.56964      -117.72691
# 2  Aliso Viejo       33.56964      -117.72691
# 3  Aliso Viejo       33.56964      -117.72691
# 4  Aliso Viejo       33.56964      -117.72691
#
#                                             Hospital  Hospital Latitude  \
# 0                              Banfield Pet Hospital          33.574345
# 1                              Banfield Pet Hospital          33.553545
# 2               VCA Laguna Grove Veterinary Hospital          33.541845
# 3  Pacific Cardiovascular Associates - Saddleback...          33.609940
# 4                    South Coast Veterinary Hospital          33.526893
#
#    Hospital Longitude                                         Categories
# 0         -117.725606  [{'id': '4d954af4a243a5684765b473', 'name': 'V...
# 1         -117.687119  [{'id': '4d954af4a243a5684765b473', 'name': 'V...
# 2         -117.692416  [{'id': '4d954af4a243a5684765b473', 'name': 'V...
# 3         -117.711321  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...
# 4         -117.713766  [{'id': '4d954af4a243a5684765b473', 'name': 'V...

# %%
# Identify results categories

def get_Category_type(row):
    try:
        categories_list = row['Categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
local_hospitals['Categories'] = local_hospitals.apply(get_Category_type, axis=1)
local_hospitals.columns = [column.split('.')[-1] for column in local_hospitals.columns]

# Include only Hospitals and Medical Centers
local_hospitals = local_hospitals[(local_hospitals['Categories'] == 'Hospital') | (local_hospitals['Categories'] == 'Medical Center')]

# Exclude hospital names that contain animal, pet, etc.
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Animal', 'animal')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Pet', 'pet')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Vet', 'vet')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Floor', 'floor')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Room', 'room')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Delivery', 'delivery')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Lab',' lab')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Cafe', 'cafe')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Lobby',' lobby')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Department', 'department')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Institude', 'institude')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Service', 'service')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Program', 'program')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Rehab', 'rehab')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Pick', 'pick')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Classroom', 'classroom')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('West', 'west')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('East', 'east')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('North', 'north')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('South', 'south')]
local_hospitals = local_hospitals[~local_hospitals['Hospital'].str.contains('Boardroom', 'boardroom')]

local_hospitals = local_hospitals.reset_index(drop = True)
print(local_hospitals.shape)
local_hospitals
# Out:
# (243, 7)
#             City  City Latitude  City Longitude  \
# 0    Aliso Viejo       33.56964      -117.72691
# 1    Aliso Viejo       33.56964      -117.72691
# 2    Aliso Viejo       33.56964      -117.72691
# 3        Anaheim       33.83286      -117.91524
# 4        Anaheim       33.83286      -117.91524
# 5        Anaheim       33.83286      -117.91524
# 6        Anaheim       33.83286      -117.91524
# 7           Brea       33.91759      -117.88899
# 8           Brea       33.91759      -117.88899
# 9           Brea       33.91759      -117.88899
# 10          Brea       33.91759      -117.88899
# 11          Brea       33.91759      -117.88899
# 12          Brea       33.91759      -117.88899
# 13          Brea       33.91759      -117.88899
# 14    Buena Park       33.86520      -117.99804
# 15    Buena Park       33.86520      -117.99804
# 16    Buena Park       33.86520      -117.99804
# 17    Costa Mesa       33.66389      -117.90239
# 18    Costa Mesa       33.66389      -117.90239
# 19    Costa Mesa       33.66389      -117.90239
# 20    Costa Mesa       33.66389      -117.90239
# 21    Costa Mesa       33.66389      -117.90239
# 22    Costa Mesa       33.66389      -117.90239
# 23    Costa Mesa       33.66389      -117.90239
# 24    Costa Mesa       33.66389      -117.90239
# 25    Costa Mesa       33.66389      -117.90239
# 26    Costa Mesa       33.66389      -117.90239
# 27    Costa Mesa       33.66389      -117.90239
# 28    Costa Mesa       33.66389      -117.90239
# 29       Cypress       33.82434      -118.03723
# ..           ...            ...             ...
# 213       Tustin       33.74425      -117.81883
# 214       Tustin       33.74425      -117.81883
# 215       Tustin       33.74425      -117.81883
# 216       Tustin       33.74425      -117.81883
# 217       Tustin       33.74425      -117.81883
# 218       Tustin       33.74425      -117.81883
# 219       Tustin       33.74425      -117.81883
# 220   Villa Park       33.81407      -117.82057
# 221   Villa Park       33.81407      -117.82057
# 222   Villa Park       33.81407      -117.82057
# 223   Villa Park       33.81407      -117.82057
# 224   Villa Park       33.81407      -117.82057
# 225   Villa Park       33.81407      -117.82057
# 226   Villa Park       33.81407      -117.82057
# 227   Villa Park       33.81407      -117.82057
# 228   Villa Park       33.81407      -117.82057
# 229   Villa Park       33.81407      -117.82057
# 230   Villa Park       33.81407      -117.82057
# 231   Villa Park       33.81407      -117.82057
# 232   Villa Park       33.81407      -117.82057
# 233  Westminster       33.75931      -117.98576
# 234  Westminster       33.75931      -117.98576
# 235  Westminster       33.75931      -117.98576
# 236  Westminster       33.75931      -117.98576
# 237  Westminster       33.75931      -117.98576
# 238  Yorba Linda       33.89152      -117.82432
# 239  Yorba Linda       33.89152      -117.82432
# 240  Yorba Linda       33.89152      -117.82432
# 241  Yorba Linda       33.89152      -117.82432
# 242  Yorba Linda       33.89152      -117.82432
#
#                                               Hospital  Hospital Latitude  \
# 0                 Mission Hospital - Cardiac Telemetry          33.569755
# 1                               Mission Hospital O. R.          33.594256
# 2                   Saddleback Memorial Medical Center          33.608810
# 3                  AHMC Anaheim Regional Medical Tower          33.847422
# 4                 AHMC Anaheim Regional Medical Center          33.848175
# 5                           kaiser permanente Hospital          33.789782
# 6                                   UCI Medical Center          33.788097
# 7                              Kindred Hospital - Brea          33.933706
# 8                           Kaiser Permanente Hospital          33.924623
# 9                             Placentia-Linda Hospital          33.886986
# 10                 Kindred Hospital Brea Subacute Unit          33.934445
# 11                                    st jude hospital          33.899788
# 12                Presbyterian Intercommunity Hospital          33.935830
# 13                      St Jude Heritage Medical Group          33.889589
# 14                          Kindred Hospital La Mirada          33.916561
# 15                    La Palma Intercommunity Hospital          33.847533
# 16                           Scripps Memorial Hospital          33.861554
# 17                         Hoag Hospital Newport Beach          33.624743
# 18                         College Hospital Costa Mesa          33.651807
# 19                                   Hoag Hospital CCU          33.625692
# 20                        Coastal Communities Hospital          33.711114
# 21                          Kaiser Permanente Hospital          33.701280
# 22                      Hoag Hospital Women's Pavilion          33.624785
# 23                 Hoag Memorial Presbyterian Hospital          33.624318
# 24                               Hoag Hospital Hallway          33.625203
# 25                    Mesa Verde Convalescent Hospital          33.641048
# 26                             Hoag Hospital - Riom 34          33.624593
# 27                        HOAG Hospital Surgery Lounge          33.624320
# 28          Hoag Hospital Registration and Information          33.616421
# 29                    La Palma Intercommunity Hospital          33.847533
# ..                                                 ...                ...
# 213  St. Joseph Hospital - Orange Center for Breast...          33.779797
# 214  St. Joseph Hospital - Orange Center for Pelvic...          33.779736
# 215       St. Joseph Hospital - Orange Infusion Center          33.779524
# 216     St. Joseph Hospital - Orange Wound Care Center          33.779949
# 217                       St. Joseph Hospital - Orange          33.781123
# 218               Children's Hospital of Orange County          33.780995
# 219                   HealthBridge Children's Hospital          33.782813
# 220                           CHOC Children's Hospital          33.780322
# 221                         St. Joseph Hospital Orange          33.780133
# 222  St. Joseph Hospital - Orange La Amistad Health...          33.782043
# 223                       St. Joseph Hospital - Orange          33.781123
# 224  St. Joseph Hospital - Orange Palliative Care C...          33.779809
# 225  St. Joseph Hospital - Orange Center for Breast...          33.779797
# 226  St. Joseph Hospital - Orange Center for Pelvic...          33.779736
# 227  St. Joseph Hospital - Orange Mother-Baby Asses...          33.782721
# 228     St. Joseph Hospital - Orange Wound Care Center          33.779949
# 229       St. Joseph Hospital - Orange Infusion Center          33.779524
# 230                                  KC's Hospital Bed          33.788463
# 231                   HealthBridge Children's Hospital          33.782813
# 232               Children's Hospital of Orange County          33.780995
# 233              Extended care hospital of westminster          33.761679
# 234                      Fountain Valley Hospital Xray          33.787500
# 235                          Huntington Beach Hospital          33.703640
# 236                   Huntington Beach Hospital Rm 427          33.701349
# 237                           Anaheim General Hospital          33.815799
# 238                           Placentia-Linda Hospital          33.886986
# 239                     St Jude Heritage Medical Group          33.889589
# 240                          Kaiser Hospital 4th floor          33.853213
# 241  Kaiser Permanente Orange County - Anaheim Medi...          33.852353
# 242                         Kaiser Permanente Hospital          33.924623
#
#      Hospital Longitude      Categories
# 0           -117.709308        Hospital
# 1           -117.700358        Hospital
# 2           -117.709162        Hospital
# 3           -117.934507        Hospital
# 4           -117.934526        Hospital
# 5           -117.898449        Hospital
# 6           -117.889314        Hospital
# 7           -117.894114        Hospital
# 8           -117.876342        Hospital
# 9           -117.842751        Hospital
# 10          -117.894002        Hospital
# 11          -117.927528  Medical Center
# 12          -117.937695        Hospital
# 13          -117.837303  Medical Center
# 14          -118.013675        Hospital
# 15          -118.038414        Hospital
# 16          -118.040424        Hospital
# 17          -117.930047        Hospital
# 18          -117.912123        Hospital
# 19          -117.929955        Hospital
# 20          -117.884851        Hospital
# 21          -117.918501        Hospital
# 22          -117.929290  Medical Center
# 23          -117.930246        Hospital
# 24          -117.928753        Hospital
# 25          -117.925935        Hospital
# 26          -117.929165  Medical Center
# 27          -117.929637        Hospital
# 28          -117.930573        Hospital
# 29          -118.038414        Hospital
# ..                  ...             ...
# 213         -117.863602  Medical Center
# 214         -117.863675  Medical Center
# 215         -117.865236  Medical Center
# 216         -117.865174        Hospital
# 217         -117.864236        Hospital
# 218         -117.865790        Hospital
# 219         -117.833892        Hospital
# 220         -117.865826        Hospital
# 221         -117.863652        Hospital
# 222         -117.860226  Medical Center
# 223         -117.864236        Hospital
# 224         -117.863561  Medical Center
# 225         -117.863602  Medical Center
# 226         -117.863675  Medical Center
# 227         -117.866977  Medical Center
# 228         -117.865174        Hospital
# 229         -117.865236  Medical Center
# 230         -117.826561        Hospital
# 231         -117.833892        Hospital
# 232         -117.865790        Hospital
# 233         -117.994560        Hospital
# 234         -117.958288        Hospital
# 235         -117.986656        Hospital
# 236         -117.986399        Hospital
# 237         -118.007058        Hospital
# 238         -117.842751        Hospital
# 239         -117.837303  Medical Center
# 240         -117.811431        Hospital
# 241         -117.845220        Hospital
# 242         -117.876342        Hospital
#
# [243 rows x 7 columns]

# %%
# Let's identify how many hospitals in each city
print(local_hospitals["City"].value_counts())
# Out:
# Garden Grove            15
# Santa Ana               14
# Villa Park              13
# Orange                  13
# Costa Mesa              12
# Tustin                  11
# Fountain Valley         11
# Newport Beach           11
# Dana Point              10
# Laguna Niguel           10
# Ladera Ranch            10
# Midway City             10
# Los Alamitos            10
# Seal Beach               8
# Brea                     7
# Laguna Beach             7
# La Palma                 5
# Westminster              5
# La Habra                 5
# Placentia                5
# Yorba Linda              5
# Cypress                  5
# Stanton                  4
# San Juan Capistrano      4
# Anaheim                  4
# Laguna Hills             3
# Fullerton                3
# Mission Viejo            3
# Aliso Viejo              3
# Buena Park               3
# Laguna Woods             3
# Huntington Beach         3
# Lake Forest              3
# Irvine                   2
# San Clemente             1
# Trabuco Canyon           1
# Rancho Mission Viejo     1
# Name: City, dtype: int64

# %%
df_hos = local_hospitals['City'].value_counts().rename_axis('City').reset_index(name='Number of Hospitals')
print(df_hos.shape)
df_hos.head()
# Out:
# (37, 2)
#            City  Number of Hospitals
# 0  Garden Grove                   15
# 1     Santa Ana                   14
# 2    Villa Park                   13
# 3        Orange                   13
# 4    Costa Mesa                   12

# %% [markdown]
# ## 8. Visualize Local Hospitals with Folium

# %%
# Create bar chart to visualize the hospital distributions in Orange County
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

city_name = local_hospitals['City'].value_counts().to_list()

local_hospitals['City'].value_counts().plot(kind='barh', figsize=(20,10))
plt.pyplot.title('Healthercare Distribution in Orange County') 
plt.pyplot.ylabel('Number of Hospitals')
plt.pyplot.xlabel('Number of Cities') 

plt.pyplot.show()

# %%
hos_map = folium.Map(location=[irvine_lat, irvine_lng], zoom_start=11)

# add markers to map
for lat, lng, label in zip(local_hospitals['Hospital Latitude'], 
                           local_hospitals['Hospital Longitude'], 
                           local_hospitals['Hospital']):
    
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(hos_map)  
    
hos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a new dataframe by merging the two tables 
# One for city total cases and one for local hospitals, for K-means clustering

df_merged = df.join(local_hospitals.set_index(['City', 'City Latitude', 'City Longitude']), 
                    on = ['City', 'City Latitude', 'City Longitude'])
df_merged = df_merged.reset_index(drop = True)
df_merged.head()
# Out:
#           City Total Cases  City Latitude  City Longitude  \
# 0  Aliso Viejo          18       33.56964      -117.72691
# 1  Aliso Viejo          18       33.56964      -117.72691
# 2  Aliso Viejo          18       33.56964      -117.72691
# 3      Anaheim         316       33.83286      -117.91524
# 4      Anaheim         316       33.83286      -117.91524
#
#                                Hospital  Hospital Latitude  \
# 0  Mission Hospital - Cardiac Telemetry          33.569755
# 1                Mission Hospital O. R.          33.594256
# 2    Saddleback Memorial Medical Center          33.608810
# 3   AHMC Anaheim Regional Medical Tower          33.847422
# 4  AHMC Anaheim Regional Medical Center          33.848175
#
#    Hospital Longitude Categories
# 0         -117.709308   Hospital
# 1         -117.700358   Hospital
# 2         -117.709162   Hospital
# 3         -117.934507   Hospital
# 4         -117.934526   Hospital

# %%
# Let's create a new dataframe that only contains numerical information
df1 = df_merged.drop(['Hospital Latitude', 'Hospital Longitude', 'Hospital', 'Categories'], 1). drop_duplicates()

# Reorder our new dataframe and show the number of hospitals accordingly
df_new = pd.merge(df1, df_hos, on='City')

print(df_new.shape)
df_new.head()
# Out:
# (37, 5)
#           City Total Cases  City Latitude  City Longitude  Number of Hospitals
# 0  Aliso Viejo          18       33.56964      -117.72691                    3
# 1      Anaheim         316       33.83286      -117.91524                    4
# 2         Brea          20       33.91759      -117.88899                    7
# 3   Buena Park          76       33.86520      -117.99804                    3
# 4   Costa Mesa          38       33.66389      -117.90239                   12

# %%
# Change "Total Cases" column type to integer
df_new['Total Cases'] = df_new['Total Cases'].astype(int)
df_new.dtypes

# Add another column called "Harship Index" which measure if healthcare system in each
# city is overwhelmed. It is calculated as, Total Cases/Number of Hospitals, columns are normalized
# Higher the "Hardship Index", worse the healthcare system is handling, thus reaching its healthcare maximun capacity

# First we normalize the inputs

df_new['Total_z'] = (df_new['Total Cases'] - df_new['Total Cases'].mean())/df_new['Total Cases'].std(ddof=0)
df_new['Hospitals_z'] = (df_new['Number of Hospitals'] - df_new['Number of Hospitals'].mean())/df_new['Number of Hospitals'].std(ddof=0)

df_new['Hardship Index'] = df_new['Total_z']/df_new['Hospitals_z']

print(df_new.shape)
df_new.head()
# Out:
# (37, 8)
#           City  Total Cases  City Latitude  City Longitude  \
# 0  Aliso Viejo           18       33.56964      -117.72691
# 1      Anaheim          316       33.83286      -117.91524
# 2         Brea           20       33.91759      -117.88899
# 3   Buena Park           76       33.86520      -117.99804
# 4   Costa Mesa           38       33.66389      -117.90239
#
#    Number of Hospitals   Total_z  Hospitals_z  Hardship Index
# 0                    3 -0.538150    -0.879297        0.612023
# 1                    4  3.441491    -0.632827       -5.438279
# 2                    7 -0.511441     0.106581       -4.798597
# 3                    3  0.236411    -0.879297       -0.268863
# 4                   12 -0.271060     1.338929       -0.202446

# %% [markdown]
# ## 10. Cluster and Visualize the Healthcare Hardship
#
# According to Hardship Index, we now can cluster cities into different catagories.

# %%
# Generate 3 clusters by categorizing total cases
clusters = np.linspace(min(df_new['Hardship Index']), max(df_new['Hardship Index']), 4)

# Cluster into groups
cluster_names = ['1', '2', '3']
df_new['Healthcare Capacity'] = pd.cut(df_new['Hardship Index'], clusters, labels=cluster_names, include_lowest=True )
df_new.head()
# Out:
#           City  Total Cases  City Latitude  City Longitude  \
# 0  Aliso Viejo           18       33.56964      -117.72691
# 1      Anaheim          316       33.83286      -117.91524
# 2         Brea           20       33.91759      -117.88899
# 3   Buena Park           76       33.86520      -117.99804
# 4   Costa Mesa           38       33.66389      -117.90239
#
#    Number of Hospitals   Total_z  Hospitals_z  Hardship Index  \
# 0                    3 -0.538150    -0.879297        0.612023
# 1                    4  3.441491    -0.632827       -5.438279
# 2                    7 -0.511441     0.106581       -4.798597
# 3                    3  0.236411    -0.879297       -0.268863
# 4                   12 -0.271060     1.338929       -0.202446
#
#   Healthcare Capacity
# 0                   3
# 1                   1
# 2                   1
# 3                   3
# 4                   3

# %%
# Cluster 1: 
df_new[df_new['Healthcare Capacity'] == '1']
# Out:
#       City  Total Cases  City Latitude  City Longitude  Number of Hospitals  \
# 1  Anaheim          316       33.83286      -117.91524                    4
# 2     Brea           20       33.91759      -117.88899                    7
#
#     Total_z  Hospitals_z  Hardship Index Healthcare Capacity
# 1  3.441491    -0.632827       -5.438279                   1
# 2 -0.511441     0.106581       -4.798597                   1

# %%
# Cluster 2: 
df_new[df_new['Healthcare Capacity'] == '2']
# Out:
#                 City  Total Cases  City Latitude  City Longitude  \
# 6         Dana Point           23       33.48054      -117.69765
# 10  Huntington Beach          214       33.67893      -118.00157
# 11            Irvine          126       33.68730      -117.82591
# 14      Ladera Ranch           12       33.57046      -117.63927
# 15      Laguna Beach           37       33.54536      -117.78153
# 20      Los Alamitos           22       33.80316      -118.07662
# 21       Midway City            6       33.74469      -117.98647
# 30        Seal Beach           11       33.74256      -118.10517
#
#     Number of Hospitals   Total_z  Hospitals_z  Hardship Index  \
# 6                    10 -0.471378     0.845990       -0.557191
# 10                    3  2.079332    -0.879297       -2.364767
# 11                    2  0.904136    -1.125766       -0.803129
# 14                   10 -0.618277     0.845990       -0.730833
# 15                    7 -0.284415     0.106581       -2.668521
# 20                   10 -0.484732     0.845990       -0.572976
# 21                   10 -0.698404     0.845990       -0.825547
# 30                    8 -0.631632     0.353051       -1.789067
#
#    Healthcare Capacity
# 6                    2
# 10                   2
# 11                   2
# 14                   2
# 15                   2
# 20                   2
# 21                   2
# 30                   2

# %%
# Cluster 3: 
df_new[df_new['Healthcare Capacity'] == '3']
# Out:
#                     City  Total Cases  City Latitude  City Longitude  \
# 0            Aliso Viejo           18       33.56964      -117.72691
# 3             Buena Park           76       33.86520      -117.99804
# 4             Costa Mesa           38       33.66389      -117.90239
# 5                Cypress           42       33.82434      -118.03723
# 7        Fountain Valley           31       33.70907      -117.95028
# 8              Fullerton           74       33.87033      -117.92896
# 9           Garden Grove           99       33.77607      -117.93611
# 12              La Habra           46       33.93187      -117.94348
# 13              La Palma           14       33.84847      -118.03727
# 16          Laguna Hills           20       33.60186      -117.69095
# 17         Laguna Niguel           32       33.56065      -117.70822
# 18          Laguna Woods            8       33.61256      -117.71872
# 19           Lake Forest           28       33.62825      -117.71743
# 22         Mission Viejo           42       33.62007      -117.67709
# 23         Newport Beach           97       33.61703      -117.93033
# 24                Orange           84       33.78787      -117.85071
# 25             Placentia           52       33.87121      -117.86020
# 26  Rancho Mission Viejo            6       33.48058      -117.56755
# 27          San Clemente           45       33.43024      -117.60698
# 28   San Juan Capistrano           24       33.49789      -117.66539
# 29             Santa Ana          330       33.74958      -117.87446
# 31               Stanton           23       33.80295      -117.99624
# 32        Trabuco Canyon           10       33.66092      -117.59022
# 33                Tustin           38       33.74425      -117.81883
# 34            Villa Park            5       33.81407      -117.82057
# 35           Westminster           40       33.75931      -117.98576
# 36           Yorba Linda           48       33.89152      -117.82432
#
#     Number of Hospitals   Total_z  Hospitals_z  Hardship Index  \
# 0                     3 -0.538150    -0.879297        0.612023
# 3                     3  0.236411    -0.879297       -0.268863
# 4                    12 -0.271060     1.338929       -0.202446
# 5                     5 -0.217642    -0.386358        0.563318
# 7                    11 -0.364542     1.092460       -0.333689
# 8                     3  0.209702    -0.879297       -0.238488
# 9                    15  0.543564     2.078338        0.261538
# 12                    5 -0.164224    -0.386358        0.425058
# 13                    5 -0.591568    -0.386358        1.531142
# 16                    3 -0.511441    -0.879297        0.581648
# 17                   10 -0.351187     0.845990       -0.415120
# 18                    3 -0.671695    -0.879297        0.763901
# 19                    3 -0.404605    -0.879297        0.460146
# 22                    3 -0.217642    -0.879297        0.247519
# 23                   11  0.516855     1.092460        0.473112
# 24                   13  0.343247     1.585399        0.216505
# 25                    5 -0.084097    -0.386358        0.217667
# 26                    1 -0.698404    -1.372236        0.508954
# 27                    1 -0.177579    -1.372236        0.129408
# 28                    4 -0.458023    -0.632827        0.723773
# 29                   14  3.628454     1.831868        1.980739
# 31                    4 -0.471378    -0.632827        0.744876
# 32                    1 -0.644986    -1.372236        0.470026
# 33                   11 -0.271060     1.092460       -0.248119
# 34                   13 -0.711759     1.585399       -0.448946
# 35                    5 -0.244351    -0.386358        0.632448
# 36                    5 -0.137515    -0.386358        0.355927
#
#    Healthcare Capacity
# 0                    3
# 3                    3
# 4                    3
# 5                    3
# 7                    3
# 8                    3
# 9                    3
# 12                   3
# 13                   3
# 16                   3
# 17                   3
# 18                   3
# 19                   3
# 22                   3
# 23                   3
# 24                   3
# 25                   3
# 26                   3
# 27                   3
# 28                   3
# 29                   3
# 31                   3
# 32                   3
# 33                   3
# 34                   3
# 35                   3
# 36                   3

# %% [markdown]
# ## 11. Final Data Visualization

# %%
# Create bar chart to visualize the overal healthcare system capacity in Orange County
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

pyplot.bar(['Cluster 3', 'Cluster 2', 'Cluster 1'], df_new["Healthcare Capacity"].value_counts(), color = ('g', 'orange', 'r'))


plt.pyplot.title('Community Healthcare System Capacity in Orange County') 
plt.pyplot.ylabel('Number of Cities')
plt.pyplot.xlabel('Healthcare Capacity') 

plt.pyplot.show()

# %%
df_new['Healthcare Capacity'] = df_new['Healthcare Capacity'].astype('category').cat.codes
df_new.dtypes
# Out:
# City                    object
# Total Cases              int64
# City Latitude          float64
# City Longitude         float64
# Number of Hospitals      int64
# Total_z                float64
# Hospitals_z            float64
# Hardship Index         float64
# Healthcare Capacity       int8
# dtype: object

# %%
# Visualize three clusters on the map

map_clusters = folium.Map(location=[irvine_lat, irvine_lng], zoom_start=11)


# Set color scheme for the clusters
x = np.arange(4)
ys = [i + x + (i*x)**2 for i in range(4)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, cluster in zip(df_new['City Latitude'], df_new['City Longitude'], df_new['Healthcare Capacity']):
    #label = folium.Popup(str(city)+ ','+str(state) + '- Cluster ' + str(cluster), parse_html=True)
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=5,
        #popup=label,
        tooltip = str(cluster),
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
